# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement resquests
# ERROR: No matching distribution found for resquests

# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
url = 'https://www.senamhi.gob.pe/?&p=estaciones'

# %%
response = requests.get(url)
response #200 means it went through
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="" name="description"/>
# <meta content="" name="author"/>
# <link href="favicon.ico" rel="icon"/>
# <title>SENAMHI - Perú</title>
# <link href="https://fonts.googleapis.com/css?family=Raleway:400,500,600,700,800,900" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans|Roboto:100,300,400,500,600,700,800,900" rel="stylesheet"/>
# <!-- Bootstrap core CSS -->
# <link href="public/lib/bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
# <!-- Custom styles for this template
#         <link href="public/css/product.css" rel="stylesheet">-->
# <!-- estilos -->
# <link href="public/css/style.css" rel="stylesheet"/>
# <!--menu
#         <style type="text/css">
#             .dropdown:hover>.dropdown-menu {
#                 display: block;
#             }
#         </style>
#         <!--fin menu-->
# <script src="public/lib/jquery/jquery-3.2.1.min.js"></script>
# <!-- google -->
# <script>
#             (function (i, s, o, g, r, a, m) {
#                 i['GoogleAnalyticsObject'] = r;
#                 i[r] = i[r] || function () {
#                     (i[r].q = i[r].q || []).push(arguments)
#                 }, i[r].l = 1 * new Date();
#                 a = s.createElement(o),
#                         m = s.getElementsByTagName(o)[0];
#                 a.async = 1;
#                 a.src = g;
#                 m.parentNode.insertBefore(a, m)
#             })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#             ga('create', 'UA-9445737-1', 'auto');
#             ga('send', 'pageview');
#         </script>
# <script type="text/javascript">
#
#             var pagInicio = 'estaciones';
#
#             $(document).ready(function () {
#
#                 if(pagInicio == 'nacional_msj'){
#
#                     //$('#myModal').modal('show');
#
#                 }
#
#             });
#
#             /*$(window).on('load',function(){
#                 $('#myModal').modal('show');
#             });*/
#         </script>
# </head>
# <body>
# <div class="container bg-header d-none d-sm-block">
# <div class="row">
# <div class="col-lg-6">
# <a class="navbar-brand" href="http://www.minam.gob.pe" target="_blank"><img alt="logo MINAM" class="logo d-inline-block align-middle" height="45px" src="public/images/logo-minam.png"/></a>
# <!--<a class="navbar-brand" href="https://www.senamhi.gob.pe"><img src="public/images/logo-senamhi.svg" height="52px" class="logo d-inline-block align-middle" alt="logo SENAMHI" /></a>-->
# <a class="navbar-brand" href="https://www.senamhi.gob.pe"><img alt="logo SENAMHI" class="logo d-inline-block align-middle" height="48px" src="public/images/logo-senamhi.svg"/></a>
# </div>
# <div class="col-lg-6 text-right">
# <a class="navbar-brand" href="http://www.transparencia.gob.pe/enlaces/pte_transparencia_enlaces.aspx?id_entidad=87#.XG9BzKIzaUl" target="_blank"><img alt="logo Portal de Transparencia" class="logo d-inline-block align-middle" height="39px" src="public/images/logo-portal-pte.png"/></a>
# </div>
# </div>
# </div>
# <nav class="navbar navbar-expand-lg navbar-light text-center menu-header bg-menu">
# <div class="d-block d-sm-none">
# <a class="navbar-brand" href="http://www.minam.gob.pe" target="_blank"><img alt="logo MINAM" class="logo d-inline-block align-middle" height="30px" src="public/images/logo-minam.png"/></a>
# <a class="navbar-brand" href="https://www.senamhi.gob.pe"><img alt="logo SENAMHI" class="logo d-inline-block align-middle" height="37px" src="public/images/logo-senamhi.svg"/></a>
# </div>
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler ml-auto" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"> </span>
# </button>
# <div class="collapse navbar-collapse justify-content-md-center" id="navbarSupportedContent">
# <ul class="navbar-nav">
# <li class="nav-item ml-3 mr-3"><a class="nav-link active" href="http://www.senamhi.gob.pe"><img alt="Inicio" src="public/images/home.svg" width="25px"/></a></li>
# <li class="nav-item dropdown ml-3 mr-3">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle depa-activo" data-toggle="dropdown" href="#" id="dropdown01">Perú</a>
# <div aria-labelledby="dropdown01" class="dropdown-menu">
# <a class="dropdown-item" href="main.php?dp=amazonas&amp;p=estaciones">Amazonas</a>
# <a class="dropdown-item" href="main.php?dp=ancash&amp;p=estaciones">Áncash</a>
# <a class="dropdown-item" href="main.php?dp=apurimac&amp;p=estaciones">Apurímac</a>
# <a class="dropdown-item" href="main.php?dp=arequipa&amp;p=estaciones">Arequipa</a>
# <a class="dropdown-item" href="main.php?dp=ayacucho&amp;p=estaciones">Ayacucho</a>
# <a class="dropdown-item" href="main.php?dp=cajamarca&amp;p=estaciones">Cajamarca</a>
# <a class="dropdown-item" href="main.php?dp=cusco&amp;p=estaciones">Cusco</a>
# <a class="dropdown-item" href="main.php?dp=huancavelica&amp;p=estaciones">Huancavelíca</a>
# <a class="dropdown-item" href="main.php?dp=huanuco&amp;p=estaciones">Huánuco</a>
# <a class="dropdown-item" href="main.php?dp=ica&amp;p=estaciones">Ica</a>
# <a class="dropdown-item" href="main.php?dp=junin&amp;p=estaciones">Junín</a>
# <a class="dropdown-item" href="main.php?dp=la-libertad&amp;p=estaciones">La Libertad</a>
# <a class="dropdown-item" href="main.php?dp=lambayeque&amp;p=estaciones">Lambayeque</a>
# <a class="dropdown-item" href="main.php?dp=lima&amp;p=estaciones">Lima</a>
# <a class="dropdown-item" href="main.php?dp=loreto&amp;p=estaciones">Loreto</a>
# <a class="dropdown-item" href="main.php?dp=madre-de-dios&amp;p=estaciones">Madre de Dios</a>
# <a class="dropdown-item" href="main.php?dp=moquegua&amp;p=estaciones">Moquegua</a>
# <a class="dropdown-item" href="main.php?dp=pasco&amp;p=estaciones">Pasco</a>
# <a class="dropdown-item" href="main.php?dp=piura&amp;p=estaciones">Piura</a>
# <a class="dropdown-item" href="main.php?dp=puno&amp;p=estaciones">Puno</a>
# <a class="dropdown-item" href="main.php?dp=san-martin&amp;p=estaciones">San Martín</a>
# <a class="dropdown-item" href="main.php?dp=tacna&amp;p=estaciones">Tacna</a>
# <a class="dropdown-item" href="main.php?dp=tumbes&amp;p=estaciones">Tumbes</a>
# <a class="dropdown-item" href="main.php?dp=ucayali&amp;p=estaciones">Ucayali</a>
# </div>
# </li>
# <li class="nav-item dropdown ml-3 mr-3">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="dropdown01">Tiempo</a>
# <div aria-labelledby="dropdown01" class="dropdown-menu">
# <a class="dropdown-item" href="?&amp;p=monitoreo-de-temperatura">Monitoreo de temperatura</a>
# <a class="dropdown-item" href="?&amp;p=pronostico-meteorologico">Pronóstico meteorológico</a>
# <a class="dropdown-item" href="?&amp;p=reportes-nowcasting" title="Aviso de lluvia a muy corto plazo">Aviso de lluvia a muy corto plazo</a>
# <a class="dropdown-item" href="?&amp;p=aviso-24H" title="Aviso de lluvia a corto plazo (24H)">Aviso de lluvia a corto plazo (24H)</a>
# <!--
#                             <a class="dropdown-item" href="?&p=reportes-nowcasting" title="Pron&oacute;stico a muy corto plazo">Pron&oacute;stico a muy corto plazo (Nowcasting)</a>
#                             -->
# <a class="dropdown-item" href="?&amp;p=aviso-meteorologico">Aviso meteorológico</a>
# <a class="dropdown-item" href="?&amp;p=radiacion-uv">Radiación UV</a>
# <a class="dropdown-item" href="?&amp;p=calidad-del-aire">Calidad del aire</a>
# <a class="dropdown-item" href="?&amp;p=satelites-goes16">Imágenes de satélite</a>
# <a class="dropdown-item" href="https://www.senamhi.gob.pe/site/volcan/" target="_blank">Vigilancia de Volcanes</a>
# <a class="dropdown-item" href="https://www.senamhi.gob.pe/site/incendio/" target="_blank">Incendios Forestales</a>
# </div>
# </li>
# <li class="nav-item dropdown ml-3 mr-3">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="dropdown01">Clima</a>
# <div aria-labelledby="dropdown01" class="dropdown-menu">
# <a class="dropdown-item" href="?&amp;p=condiciones-climaticas">Condiciones Climáticas actuales</a>
# <a class="dropdown-item" href="?&amp;p=pronostico-climatico">Pronóstico climático</a>
# <a class="dropdown-item" href="?&amp;p=fenomeno-el-nino">El Niño</a>
# <a class="dropdown-item" href="?&amp;p=mapa-climatico-del-peru">Mapa climático nacional</a>
# <a class="dropdown-item" href="?&amp;p=heladas-y-friajes">Heladas, friajes y nevadas</a>
# </div>
# </li>
# <li class="nav-item dropdown ml-3 mr-3">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="dropdown02">Hidrología</a>
# <div aria-labelledby="dropdown02" class="dropdown-menu">
# <a class="dropdown-item" href="?&amp;p=monitoreo-hidrologico">Monitoreo Hidrológico</a>
# <a class="dropdown-item" href="?&amp;p=pronostico-caudales">Pronóstico de caudales</a>
# <a class="dropdown-item" href="?&amp;p=aviso-hidrologico">Aviso de crecida de ríos</a>
# <a class="dropdown-item" href="?&amp;p=aviso-activacion-quebrada">Aviso ante posible activación de quebradas</a>
# <!--
#                             <a class="dropdown-item" href="?&p=aviso-hidrologico">Avisos hidrol&oacute;gicos</a>
#                             -->
# <a class="dropdown-item" href="?&amp;p=situacion-hidrologica-nacional" title="Información de los Ríos a Nivel Nacional">Información de los ríos a nivel nacional</a>
# <a class="dropdown-item" href="?&amp;p=sequias" target="_parent" title="Indicadores de Sequías">Indicadores de Sequías</a>
# <a class="dropdown-item" href="https://idesep.senamhi.gob.pe/dhi-idf/" target="_blank">VISOR (Curvas de Intensidad-Duración-Frecuencia)</a>
# </div>
# </li>
# <li class="nav-item dropdown ml-3 mr-3">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="dropdown03">Agrometeorología</a>
# <div aria-labelledby="dropdown03" class="dropdown-menu">
# <a class="dropdown-item" href="?&amp;p=boletin-agro">Monitoreo Agroclimático</a>
# <a class="dropdown-item" href="?&amp;p=impacto-en-la-agricultura" target="_parent" title="Monitoreo y tendencia">Pronóstico y Monitoreo Agrometeorológico</a>
# <a class="dropdown-item" href="?&amp;p=riesgo-agro">Pronóstico de Riesgo Agroclimático</a>
# <!--<a class="dropdown-item" href="#">Pron&oacute;stico agroclim&aacute;tico</a>-->
# </div>
# </li>
# <li class="nav-item dropdown ml-3 mr-3">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle active" data-toggle="dropdown" href="#" id="dropdown03">Datos</a>
# <div aria-labelledby="dropdown03" class="dropdown-menu">
# <a class="dropdown-item" href="http://idesep.senamhi.gob.pe/portalidesep/" target="_blank">Datos Espaciales - IDESEP</a>
# <a class="dropdown-item" href="?&amp;p=estaciones">Datos hidrometeorológicos</a>
# <a class="dropdown-item" href="?&amp;p=lluvia-acumulada" target="_parent" title="Lluvia Acumulada">Datos de lluvia acumulada</a>
# <a class="dropdown-item" href="?&amp;p=descarga-datos-hidrometeorologicos">Descarga de datos</a>
# <a class="dropdown-item" href="?&amp;p=solicitud-servicio" title="Solicitud de servicio">Solicitud de datos</a>
# <!--<a class="dropdown-item" href="http://geoservicios.senamhi.gob.pe:8087/portalidesep/" target="_blank">Datos espaciales - IDESEP</a>-->
# <!--
#                             <a class="dropdown-item" href="#">Solicitud de datos</a>
#                             <a class="dropdown-item" href="#">Publicaciones</a>
#                             <a class="dropdown-item" href="#">IDESEP</a>
#                             -->
# </div>
# </li>
# <li class="nav-item dropdown ml-3 mr-3">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle active" data-toggle="dropdown" href="#" id="dropdown03">Servicios al Ciudadano</a>
# <div aria-labelledby="dropdown03" class="dropdown-menu">
# <a class="dropdown-item" href="?&amp;p=tusne">Servicios (TUSNE)</a>
# <a class="dropdown-item" href="?&amp;p=tupa">TUPA</a>
# <a class="dropdown-item" href="https://reclamos.servicios.gob.pe/?institution_id=203">Libro de reclamaciones</a>
# <a class="dropdown-item" href="http://sgd.senamhi.gob.pe/sis/sgd/mant_atencion_ciudadano" target="_blank">Estado del trámite</a>
# <a class="dropdown-item" href="?&amp;p=estudios">Estudios e investigaciones</a>
# <a class="dropdown-item" href="?&amp;p=boletines" title="Boletines">Boletines</a>
# <a class="dropdown-item" href="http://repositorio.senamhi.gob.pe/" target="_blank" title="Repositorio">Repositorio Institucional</a>
# </div>
# </li>
# </ul>
# </div>
# </nav>
# <div class="container-fluid box-bg box-bg-estacion-color">
# <div class="row">
# <div class="container">
# <div class="row box-conten-int">
# <h1>Datos / Datos Hidrometeorológicos</h1>
# </div>
# </div>
# </div>
# </div>
# <div class="container box-conten-int">
# <div class="row">
# <div class="col-12">
# <!--inicio contenido-->
# <div class="col-12 col-md-12 col-lg-12">
# <h2>Datos Hidrometeorológicos a nivel nacional </h2>
# </div>
# <!--<iframe class="" src="mapas/mapa-estaciones/mapadepesta-func.php?" allowfullscreen width="100%" height="800" frameborder="0"></iframe>-->
# <!--<iframe class="" src="mapas/mapa-estaciones/mapadepesta1.php?" allowfullscreen width="100%" height="800" frameborder="0"></iframe>-->
# <iframe allowfullscreen="" class="" frameborder="0" height="900" src="mapas/mapa-estaciones-2/?" width="100%"></iframe>
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-3 col-lg-3">
# <div class="ico-leyenda-mapa-convencional-m m-1 p-4 tex" style="font-size: 14px;">
#                             Estación Meteorológica Convencional
#                         </div>
# </div>
# <div class="col-md-3 col-lg-3">
# <div class="ico-leyenda-mapa-automatica-m m-1 p-4" style="font-size: 14px;">
#                             Estación Meteorológica Automatica
#                         </div>
# </div>
# <div class="col-md-3 col-lg-3">
# <div class="ico-leyenda-mapa-convencional-h m-1 p-4" style="font-size: 14px;">
#                             Estación Hidrológica Convencional
#                         </div>
# </div>
# <div class="col-md-3 col-lg-3">
# <div class="ico-leyenda-mapa-automatica-h m-1 p-4" style="font-size: 14px;">
#                             Estación Hidrológica Automatica
#                         </div>
# </div>
# </div>
# </div>
# <!--fin contenido-->
# </div>
# </div>
# </div>
# <footer class="container-fluid box-bg box-bg-footer">
# <div class="row">
# <div class="container" style="padding: 60px 0 45px 0;">
# <div class="row">
# <div class="col-lg-6 col-md-12 col-sm-12 py-5">
# <section>
# <!--<iframe src="https://www.google.com/maps/embed/v1/place?key=AIzaSyA0s1a7phLN0iaD6-UE7m4qP-z21pH0eSc&q=SENAMHI+lima+peru" width="100%" height="450" frameborder="0" style="border:0" allowfullscreen></iframe>-->
# <!--<iframe src="https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d62415.89784046048!2d-77.06367415826386!3d-12.112589133199778!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x0%3A0xf1d42b91641910c4!2sSENAMHI!5e0!3m2!1ses-419!2spe!4v1562290591857!5m2!1ses-419!2spe" width="100%" height="450" frameborder="0" style="border:0" allowfullscreen></iframe>-->
# <iframe allowfullscreen="" frameborder="0" height="450" src="https://www.google.com/maps/embed?pb=!1m14!1m8!1m3!1d1159.9158187055843!2d-77.04302508277054!3d-12.07951660795558!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x0%3A0xf1d42b91641910c4!2sSENAMHI!5e0!3m2!1ses-419!2spe!4v1562290921296!5m2!1ses-419!2spe" style="border:0" width="100%"></iframe>
# </section>
# </div>
# <div class="col-lg-6 col-md-12 col-sm-12">
# <div class="box-conten-footer">
# <div class="col-12 col-md-12 col-lg-12">
# <h2 class="tittle-line">Contáctenos</h2>
# </div>
# <!-- 2658798 - 996369766 -->
# <!-- 6141407 -->
# <address>
# <strong class="black">SENAMHI - Sede Central</strong><br/>
# <span>Jr. Cahuide 785, Jesús María - Lima</span><br/>
# <abbr class="black" title="Phone">Central telefónica: </abbr> <a href="tel:+511 6141414">(01) 614 1414</a><br/>
# <abbr class="black" title="Phone">Atención al ciudadano: </abbr> <a href="tel:+511 4702867">(01) 470 2867</a> / <a href="tel:+511 998487805">(01) 998 487 805</a><br/>
# <abbr class="black" title="Phone">Pronóstico del tiempo: </abbr> <a href="tel:+511 2658798">(01) 265 8798</a> / <a href="tel:+511 996369766">(01) 996 369 766</a><br/>
# <abbr class="black" title="mail">Consultas: </abbr> <a href="mailto:atencionalciudadano@senamhi.gob.pe">atencionalciudadano@senamhi.gob.pe</a><br/>
# <abbr class="black" title="working">Horario de atención: </abbr>
# <br/>Atención al ciudadano: De  lunes a viernes de 8:30 a 17:15 Hrs.
#                                     <br/>Mesa de partes: De  lunes a viernes de 8:30 a 16:30 Hrs. <br/>
# <abbr class="black" title="working">Registra tus documentos: </abbr>
# <a href="malito:mesadepartes@senamhi.gob.pe">mesadepartes@senamhi.gob.pe</a><br/>
# <abbr class="black" title="mail">Consulta tu trámite: </abbr>
# <a href="tel:+511 982958271">(01) 982 958 271</a>
# </address>
# <aside>
# <a href="https://www.facebook.com/senamhiperu" target="_blank" title="enlace facebook puno"><img class="mr-3" height="25px" src="public/images/logo-bn-rs-facebook.svg"/></a>
# <a href="https://twitter.com/senamhiperu" target="_blank" title="enlace twitter puno"><img class="ml-2 mr-3" height="25px" src="public/images/logo-bn-rs-twitter.svg"/></a>
# <a href="https://www.youtube.com/channel/UCSy_etV_nlGLFlq7KTx1e9Q" target="_blank" title="enlace youtube SENAMHI"><img class="ml-2 mr-3" height="25px" src="public/images/logo-bn-rs-youtube.svg"/></a>
# <a href="https://www.flickr.com/photos/senamhiperu/" target="_blank" title="enlace flicker SENAMHI"><img class="ml-2 mr-3" height="15px" src="public/images/logo-bn-rs-flickr.svg"/></a>
# <a href="https://issuu.com/senamhi_peru" target="_blank" title="enlace issuu SENAMHI"><img class="ml-3" height="25px" src="public/images/logo-bn-rs-issuu.svg"/></a>
# </aside>
# </div>
# </div>
# </div>
# </div>
# <div class="container-fluid box-bg-footer" style="padding: 50px 0 35px 0; background: #062243; min-height: 400px;">
# <div class="container">
# <div class="row">
# <div class="col-sm-12 col-md-4 col-lg-4">
# <div class="box-conten-footer">
# <div class="col-12 col-md-12 col-lg-12">
# <h3 class="tittle-line">Institución</h3>
# </div>
# <ul>
# <li><a href="./?p=senamhi">¿Quienes Somos?</a></li>
# <li><a href="./?p=organigrama">Organigrama</a></li>
# <li><a href="./?p=funcionarios">Funcionarios</a></li>
# <li><a href="./?p=sedes">Sedes</a></li>
# <li><a href="./?p=normas">Normas Emitidas</a></li>
# <li><a href="./?p=control-interno">Control Interno</a></li>
# <li><a href="./?p=codigo-de-etica">Codigo de Ética</a></li>
# <li><a href="./?p=convocatorias">Convocatorias de Empleo</a></li>
# <li><a href="./?p=programas-y-proyectos">Programas y Proyectos</a></li>
# <li><a href="./?p=prensa">Prensa</a></li>
# <li><a href="https://www.senamhi.gob.pe/intranetsenamhi/login.php" target="_blank">Intranet</a></li>
# </ul>
# </div>
# </div>
# <div class="col-sm-12 col-md-4 col-lg-4">
# <div class="box-conten-footer">
# <div class="col-12 col-md-12 col-lg-12">
# <h3 class="tittle-line">Herramientas</h3>
# </div>
# <ul>
# <li><a href="http://idesep.senamhi.gob.pe/" target="_blank" title="IDESEP"><strong>Infraestructura de Datos Espaciales del SENAMHI PERÚ - IDESEP</strong></a></li>
# <li><a href="https://idesep.senamhi.gob.pe/dhi-idf/" target="_blank">VISOR (Curvas de Intensidad-Duración-Frecuencia)</a></li>
# <li><a href="./?p=sinoptica" title="Análisis Meteorológico">Análisis Meteorológico</a></li>
# <li><a href="./?p=aviso-meteorologico-historico" title="Análisis Meteorológico">Avisos Meteorológicos anteriores</a></li>
# <li><a href="./?p=articulos" title="Artículos Científicos">Artículos Científicos</a></li>
# <!--<li><a href="./?p=pronostico-lima" title="Pron&oacute;stico para Lima Metropolitana">Pron&oacute;stico para Lima Metropolitana</a></li>-->
# <!--<li><a href="./?p=boletines" title="Boletines">Boletines</a></li>-->
# <!--<li><a href="./?p=satelites" title="Imagenes de dat&eacute;lite GOES 16">Im&aacute;genes de Sat&eacute;lite GOES 16</a></li>-->
# <!--<li><a href="./?p=satelites-aqua" title="Imagenes de dat&eacute;lite AQUA">Im&aacute;genes de Sat&eacute;lite AQUA</a></li>-->
# <!--<li><a href="./?p=satelites-modis" title="Imagenes de dat&eacute;lite MODIS">Im&aacute;genes de Sat&eacute;lite MODIS</a></li>-->
# <!--<li><a href="./?p=datos-historicos" title="Datos Hist&oacute;ricos">Datos Hist&oacute;ricos</a></li>-->
# <li><a href="site/incendio" target="_blank" title="Incendios Forestales">Vigilancia Atmosférica de Incendios Forestales</a></li>
# <li><a href="https://www.senamhi.gob.pe/site/volcan/" target="_blank" title="Vigilancia de Volcanes">Vigilancia de Volcanes</a></li>
# <!--<li><a href="/?p=situacion-hidrologica-nacional" target="_parent" title="Informaci&oacute;n de los R&iacute;os a Nivel Nacional">Informaci&oacute;n de los R&iacute;os a Nivel Nacional</a></li>-->
# <!--<li><a href="./?p=perfil-vertical" target="_parent" title="Perfil Vertical">Perfil Vertical de la Atm&oacute;sfera</a></li>-->
# <li><a href="./?p=cambio-climatico" target="_parent" title="Cambio Climático">Cambio Climático</a></li>
# <li><a href="http://idesep.senamhi.gob.pe/indicadores/" target="_blank" title="Indicadores Climáticos">Indicadores Climáticos</a></li>
# <!--<li><a href="/?p=monitoreo-silvia" target="_blank" title="Monitoreo SILVIA">Monitoreo y Pron&oacute;stico de Movimientos en Masa - SILVIA</a></li>-->
# <li><a href="https://web2.senamhi.gob.pe" title="Versión Web anterior">Versión Web anterior</a></li>
# </ul>
# </div>
# </div>
# <div class="col-sm-12 col-md-4 col-lg-4">
# <div class="box-conten-footer">
# <div class="col-12 col-md-12 col-lg-12">
# <h3 class="tittle-line">Enlaces de Interés</h3>
# </div>
# <ul>
# <li><a href="http://www.gob.pe/8901" target="_blank">Integridad y Transparencia durante la emergencia sanitaria</a></li>
# <li><a href="http://www.minam.gob.pe/" target="_blank">Ministerio del Ambiente</a></li>
# <li><a href="http://www.wmo.int/pages/index_es.html" target="_blank">OMM</a></li>
# <li><a href="https://erecruit.wmo.int/public/" target="_blank">Anuncios OMM</a></li>
# <li><a href="http://www.peru.gob.pe/" target="_blank">Portal del Estado Peruano</a></li>
# <li><a href="http://www.congreso.gob.pe/" target="_blank">Congreso de la República</a></li>
# <li><a href="http://www.sanciones.gob.pe:8081/transparencia/" target="_blank">RNSDD</a></li>
# <li><a href="https://cloudatlas.wmo.int/es/home.html" target="_blank">Atlas Internacional de Nubes - Manual de Observación de nubes y otros meteoros</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <div class="modal" id="myModal" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-lg modal-dialog-centered" role="document">
# <div class="modal-content">
# <div class="modal-header bg-light text-dark d-none">
# <!--<h5 class="modal-title"><strong>COMUNICADO</strong></h5>-->
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body">
# <img class="img-fluid" src="public/images/banner-www.gob.pe.senamhi.jpg"/>
# </div>
# <div class="modal-footer">
# <button class="btn btn-secondary" data-dismiss="modal" type="button">Cerrar</button>
# </div>
# </div>
# </div>
# </div>
# <!-- Bootstrap core JavaScript
#         ================================================== -->
# <!-- Placed at the end of the document so the pages load faster -->
# <!-- <script>window.jQuery || document.write('<script src="js/vendor/jquery-slim.min.js"><\/script>')</script>-->
# <script src="public/lib/vendor/popper.min.js"></script>
# <script src="public/lib/bootstrap/js/bootstrap.min.js"></script>
# <script src="public/lib/vendor/holder.min.js"></script>
# <script>
#             Holder.addTheme('thumb', {
#                 bg: '#55595c',
#                 fg: '#eceeef',
#                 text: 'Thumbnail'
#             });
#         </script>
# <script>
# //            $(window).scroll(function () {
# //                if ($("#menu").offset().top > 25) {
# //                    $("#menu img").css("margin-top", "0");
# //                    $("#menu img").css("margin-bottom", "0");
# //                    $(".logo").css("height", "25px");
# //                    $("nav").css("border-bottom", "4px solid #E93400");
# //                } else {
# //                    $("#menu").removeClass("bg-inverse");
# //                    $("#menu img").css("margin-top", "3px");
# //                    $("#menu img").css("margin-bottom", "3px");
# //                    $(".logo").css("height", "35px");
# //                }
# //            });
#         </script>
# </body>
# </html>

# %%
soup.findAll('a')
# Out:
# [<a class="navbar-brand" href="http://www.minam.gob.pe" target="_blank"><img alt="logo MINAM" class="logo d-inline-block align-middle" height="45px" src="public/images/logo-minam.png"/></a>,
#  <a class="navbar-brand" href="https://www.senamhi.gob.pe"><img alt="logo SENAMHI" class="logo d-inline-block align-middle" height="48px" src="public/images/logo-senamhi.svg"/></a>,
#  <a class="navbar-brand" href="http://www.transparencia.gob.pe/enlaces/pte_transparencia_enlaces.aspx?id_entidad=87#.XG9BzKIzaUl" target="_blank"><img alt="logo Portal de Transparencia" class="logo d-inline-block align-middle" height="39px" src="public/images/logo-portal-pte.png"/></a>,
#  <a class="navbar-brand" href="http://www.minam.gob.pe" target="_blank"><img alt="logo MINAM" class="logo d-inline-block align-middle" height="30px" src="public/images/logo-minam.png"/></a>,
#  <a class="navbar-brand" href="https://www.senamhi.gob.pe"><img alt="logo SENAMHI" class="logo d-inline-block align-middle" height="37px" src="public/images/logo-senamhi.svg"/></a>,
#  <a class="nav-link active" href="http://www.senamhi.gob.pe"><img alt="Inicio" src="public/images/home.svg" width="25px"/></a>,
#  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle depa-activo" data-toggle="dropdown" href="#" id="dropdown01">Perú</a>,
#  <a class="dropdown-item" href="main.php?dp=amazonas&amp;p=estaciones">Amazonas</a>,
#  <a class="dropdown-item" href="main.php?dp=ancash&amp;p=estaciones">Áncash</a>,
#  <a class="dropdown-item" href="main.php?dp=apurimac&amp;p=estaciones">Apurímac</a>,
#  <a class="dropdown-item" href="main.php?dp=arequipa&amp;p=estaciones">Arequipa</a>,
#  <a class="dropdown-item" href="main.php?dp=ayacucho&amp;p=estaciones">Ayacucho</a>,
#  <a class="dropdown-item" href="main.php?dp=cajamarca&amp;p=estaciones">Cajamarca</a>,
#  <a class="dropdown-item" href="main.php?dp=cusco&amp;p=estaciones">Cusco</a>,
#  <a class="dropdown-item" href="main.php?dp=huancavelica&amp;p=estaciones">Huancavelíca</a>,
#  <a class="dropdown-item" href="main.php?dp=huanuco&amp;p=estaciones">Huánuco</a>,
#  <a class="dropdown-item" href="main.php?dp=ica&amp;p=estaciones">Ica</a>,
#  <a class="dropdown-item" href="main.php?dp=junin&amp;p=estaciones">Junín</a>,
#  <a class="dropdown-item" href="main.php?dp=la-libertad&amp;p=estaciones">La Libertad</a>,
#  <a class="dropdown-item" href="main.php?dp=lambayeque&amp;p=estaciones">Lambayeque</a>,
#  <a class="dropdown-item" href="main.php?dp=lima&amp;p=estaciones">Lima</a>,
#  <a class="dropdown-item" href="main.php?dp=loreto&amp;p=estaciones">Loreto</a>,
#  <a class="dropdown-item" href="main.php?dp=madre-de-dios&amp;p=estaciones">Madre de Dios</a>,
#  <a class="dropdown-item" href="main.php?dp=moquegua&amp;p=estaciones">Moquegua</a>,
#  <a class="dropdown-item" href="main.php?dp=pasco&amp;p=estaciones">Pasco</a>,
#  <a class="dropdown-item" href="main.php?dp=piura&amp;p=estaciones">Piura</a>,
#  <a class="dropdown-item" href="main.php?dp=puno&amp;p=estaciones">Puno</a>,
#  <a class="dropdown-item" href="main.php?dp=san-martin&amp;p=estaciones">San Martín</a>,
#  <a class="dropdown-item" href="main.php?dp=tacna&amp;p=estaciones">Tacna</a>,
#  <a class="dropdown-item" href="main.php?dp=tumbes&amp;p=estaciones">Tumbes</a>,
#  <a class="dropdown-item" href="main.php?dp=ucayali&amp;p=estaciones">Ucayali</a>,
#  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="dropdown01">Tiempo</a>,
#  <a class="dropdown-item" href="?&amp;p=monitoreo-de-temperatura">Monitoreo de temperatura</a>,
#  <a class="dropdown-item" href="?&amp;p=pronostico-meteorologico">Pronóstico meteorológico</a>,
#  <a class="dropdown-item" href="?&amp;p=reportes-nowcasting" title="Aviso de lluvia a muy corto plazo">Aviso de lluvia a muy corto plazo</a>,
#  <a class="dropdown-item" href="?&amp;p=aviso-24H" title="Aviso de lluvia a corto plazo (24H)">Aviso de lluvia a corto plazo (24H)</a>,
#  <a class="dropdown-item" href="?&amp;p=aviso-meteorologico">Aviso meteorológico</a>,
#  <a class="dropdown-item" href="?&amp;p=radiacion-uv">Radiación UV</a>,
#  <a class="dropdown-item" href="?&amp;p=calidad-del-aire">Calidad del aire</a>,
#  <a class="dropdown-item" href="?&amp;p=satelites-goes16">Imágenes de satélite</a>,
#  <a class="dropdown-item" href="https://www.senamhi.gob.pe/site/volcan/" target="_blank">Vigilancia de Volcanes</a>,
#  <a class="dropdown-item" href="https://www.senamhi.gob.pe/site/incendio/" target="_blank">Incendios Forestales</a>,
#  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="dropdown01">Clima</a>,
#  <a class="dropdown-item" href="?&amp;p=condiciones-climaticas">Condiciones Climáticas actuales</a>,
#  <a class="dropdown-item" href="?&amp;p=pronostico-climatico">Pronóstico climático</a>,
#  <a class="dropdown-item" href="?&amp;p=fenomeno-el-nino">El Niño</a>,
#  <a class="dropdown-item" href="?&amp;p=mapa-climatico-del-peru">Mapa climático nacional</a>,
#  <a class="dropdown-item" href="?&amp;p=heladas-y-friajes">Heladas, friajes y nevadas</a>,
#  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="dropdown02">Hidrología</a>,
#  <a class="dropdown-item" href="?&amp;p=monitoreo-hidrologico">Monitoreo Hidrológico</a>,
#  <a class="dropdown-item" href="?&amp;p=pronostico-caudales">Pronóstico de caudales</a>,
#  <a class="dropdown-item" href="?&amp;p=aviso-hidrologico">Aviso de crecida de ríos</a>,
#  <a class="dropdown-item" href="?&amp;p=aviso-activacion-quebrada">Aviso ante posible activación de quebradas</a>,
#  <a class="dropdown-item" href="?&amp;p=situacion-hidrologica-nacional" title="Información de los Ríos a Nivel Nacional">Información de los ríos a nivel nacional</a>,
#  <a class="dropdown-item" href="?&amp;p=sequias" target="_parent" title="Indicadores de Sequías">Indicadores de Sequías</a>,
#  <a class="dropdown-item" href="https://idesep.senamhi.gob.pe/dhi-idf/" target="_blank">VISOR (Curvas de Intensidad-Duración-Frecuencia)</a>,
#  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="dropdown03">Agrometeorología</a>,
#  <a class="dropdown-item" href="?&amp;p=boletin-agro">Monitoreo Agroclimático</a>,
#  <a class="dropdown-item" href="?&amp;p=impacto-en-la-agricultura" target="_parent" title="Monitoreo y tendencia">Pronóstico y Monitoreo Agrometeorológico</a>,
#  <a class="dropdown-item" href="?&amp;p=riesgo-agro">Pronóstico de Riesgo Agroclimático</a>,
#  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle active" data-toggle="dropdown" href="#" id="dropdown03">Datos</a>,
#  <a class="dropdown-item" href="http://idesep.senamhi.gob.pe/portalidesep/" target="_blank">Datos Espaciales - IDESEP</a>,
#  <a class="dropdown-item" href="?&amp;p=estaciones">Datos hidrometeorológicos</a>,
#  <a class="dropdown-item" href="?&amp;p=lluvia-acumulada" target="_parent" title="Lluvia Acumulada">Datos de lluvia acumulada</a>,
#  <a class="dropdown-item" href="?&amp;p=descarga-datos-hidrometeorologicos">Descarga de datos</a>,
#  <a class="dropdown-item" href="?&amp;p=solicitud-servicio" title="Solicitud de servicio">Solicitud de datos</a>,
#  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle active" data-toggle="dropdown" href="#" id="dropdown03">Servicios al Ciudadano</a>,
#  <a class="dropdown-item" href="?&amp;p=tusne">Servicios (TUSNE)</a>,
#  <a class="dropdown-item" href="?&amp;p=tupa">TUPA</a>,
#  <a class="dropdown-item" href="https://reclamos.servicios.gob.pe/?institution_id=203">Libro de reclamaciones</a>,
#  <a class="dropdown-item" href="http://sgd.senamhi.gob.pe/sis/sgd/mant_atencion_ciudadano" target="_blank">Estado del trámite</a>,
#  <a class="dropdown-item" href="?&amp;p=estudios">Estudios e investigaciones</a>,
#  <a class="dropdown-item" href="?&amp;p=boletines" title="Boletines">Boletines</a>,
#  <a class="dropdown-item" href="http://repositorio.senamhi.gob.pe/" target="_blank" title="Repositorio">Repositorio Institucional</a>,
#  <a href="tel:+511 6141414">(01) 614 1414</a>,
#  <a href="tel:+511 4702867">(01) 470 2867</a>,
#  <a href="tel:+511 998487805">(01) 998 487 805</a>,
#  <a href="tel:+511 2658798">(01) 265 8798</a>,
#  <a href="tel:+511 996369766">(01) 996 369 766</a>,
#  <a href="mailto:atencionalciudadano@senamhi.gob.pe">atencionalciudadano@senamhi.gob.pe</a>,
#  <a href="malito:mesadepartes@senamhi.gob.pe">mesadepartes@senamhi.gob.pe</a>,
#  <a href="tel:+511 982958271">(01) 982 958 271</a>,
#  <a href="https://www.facebook.com/senamhiperu" target="_blank" title="enlace facebook puno"><img class="mr-3" height="25px" src="public/images/logo-bn-rs-facebook.svg"/></a>,
#  <a href="https://twitter.com/senamhiperu" target="_blank" title="enlace twitter puno"><img class="ml-2 mr-3" height="25px" src="public/images/logo-bn-rs-twitter.svg"/></a>,
#  <a href="https://www.youtube.com/channel/UCSy_etV_nlGLFlq7KTx1e9Q" target="_blank" title="enlace youtube SENAMHI"><img class="ml-2 mr-3" height="25px" src="public/images/logo-bn-rs-youtube.svg"/></a>,
#  <a href="https://www.flickr.com/photos/senamhiperu/" target="_blank" title="enlace flicker SENAMHI"><img class="ml-2 mr-3" height="15px" src="public/images/logo-bn-rs-flickr.svg"/></a>,
#  <a href="https://issuu.com/senamhi_peru" target="_blank" title="enlace issuu SENAMHI"><img class="ml-3" height="25px" src="public/images/logo-bn-rs-issuu.svg"/></a>,
#  <a href="./?p=senamhi">¿Quienes Somos?</a>,
#  <a href="./?p=organigrama">Organigrama</a>,
#  <a href="./?p=funcionarios">Funcionarios</a>,
#  <a href="./?p=sedes">Sedes</a>,
#  <a href="./?p=normas">Normas Emitidas</a>,
#  <a href="./?p=control-interno">Control Interno</a>,
#  <a href="./?p=codigo-de-etica">Codigo de Ética</a>,
#  <a href="./?p=convocatorias">Convocatorias de Empleo</a>,
#  <a href="./?p=programas-y-proyectos">Programas y Proyectos</a>,
#  <a href="./?p=prensa">Prensa</a>,
#  <a href="https://www.senamhi.gob.pe/intranetsenamhi/login.php" target="_blank">Intranet</a>,
#  <a href="http://idesep.senamhi.gob.pe/" target="_blank" title="IDESEP"><strong>Infraestructura de Datos Espaciales del SENAMHI PERÚ - IDESEP</strong></a>,
#  <a href="https://idesep.senamhi.gob.pe/dhi-idf/" target="_blank">VISOR (Curvas de Intensidad-Duración-Frecuencia)</a>,
#  <a href="./?p=sinoptica" title="Análisis Meteorológico">Análisis Meteorológico</a>,
#  <a href="./?p=aviso-meteorologico-historico" title="Análisis Meteorológico">Avisos Meteorológicos anteriores</a>,
#  <a href="./?p=articulos" title="Artículos Científicos">Artículos Científicos</a>,
#  <a href="site/incendio" target="_blank" title="Incendios Forestales">Vigilancia Atmosférica de Incendios Forestales</a>,
#  <a href="https://www.senamhi.gob.pe/site/volcan/" target="_blank" title="Vigilancia de Volcanes">Vigilancia de Volcanes</a>,
#  <a href="./?p=cambio-climatico" target="_parent" title="Cambio Climático">Cambio Climático</a>,
#  <a href="http://idesep.senamhi.gob.pe/indicadores/" target="_blank" title="Indicadores Climáticos">Indicadores Climáticos</a>,
#  <a href="https://web2.senamhi.gob.pe" title="Versión Web anterior">Versión Web anterior</a>,
#  <a href="http://www.gob.pe/8901" target="_blank">Integridad y Transparencia durante la emergencia sanitaria</a>,
#  <a href="http://www.minam.gob.pe/" target="_blank">Ministerio del Ambiente</a>,
#  <a href="http://www.wmo.int/pages/index_es.html" target="_blank">OMM</a>,
#  <a href="https://erecruit.wmo.int/public/" target="_blank">Anuncios OMM</a>,
#  <a href="http://www.peru.gob.pe/" target="_blank">Portal del Estado Peruano</a>,
#  <a href="http://www.congreso.gob.pe/" target="_blank">Congreso de la República</a>,
#  <a href="http://www.sanciones.gob.pe:8081/transparencia/" target="_blank">RNSDD</a>,
#  <a href="https://cloudatlas.wmo.int/es/home.html" target="_blank">Atlas Internacional de Nubes - Manual de Observación de nubes y otros meteoros</a>]
